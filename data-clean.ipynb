# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
read_2015= pd.read_csv('datasets_894_813759_2015.csv')
read_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0              7.587                   1.39651                   0.94143
# ...

# %%
country_region= read_2015.drop(['Happiness Rank', 'Happiness Score',  'Economy (GDP per Capita)',  'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', ], axis=1)
# country_region

# %%
happiness_2016= pd.read_csv('datasets_894_813759_2016.csv')
happiness_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0              7.526                   1.44178                   0.79504
# ...

# %%
read_2017= pd.read_csv('datasets_894_813759_2017.csv')
happiness_2017 = read_2017.drop(['Whisker.high', 'Whisker.low'],axis=1)

# %%
merged_inner_2017 = pd.merge(left=country_region, right=happiness_2017, left_on='Country', right_on='Country')
merged_inner_2017
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               4
# 1        Iceland                   Western Europe               3
# 2        Denmark                   Western Europe               2
# 3         Norway                   Western Europe               1
# 4         Canada                    North America               7
# ..           ...                              ...             ...
# 144       Rwanda               Sub-Saharan Africa             151
# 145        Benin               Sub-Saharan Africa             143
# 146        Syria  Middle East and Northern Africa             152
# 147      Burundi               Sub-Saharan Africa             154
# 148         Togo               Sub-Saharan Africa             150
#
#      Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0              7.494                  1.564980                  0.858131
# ...

# %%
happiness_2018= pd.read_csv('datasets_894_813759_2018.csv')

# %%
merged_inner_2018 = pd.merge(left=country_region, right=happiness_2018, left_on='Country', right_on='Country or region')

# %%
data_2018= merged_inner_2018.drop(['Country or region'], axis=1)
data_2018
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               5
# 1        Iceland                   Western Europe               4
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               2
# 4         Canada                    North America               7
# ..           ...                              ...             ...
# 145       Rwanda               Sub-Saharan Africa             151
# 146        Benin               Sub-Saharan Africa             136
# 147        Syria  Middle East and Northern Africa             150
# 148      Burundi               Sub-Saharan Africa             156
# 149         Togo               Sub-Saharan Africa             139
#
#      Happiness Score  Economy (GDP per Capita)  Healthy (Life Expectancy)  \
# 0              7.487                     1.420                      0.927
# ...

# %%
happiness_2019= pd.read_csv('datasets_894_813759_2019.csv')

# %%
merged_inner_2019 = pd.merge(left=country_region, right=happiness_2019, left_on='Country', right_on='Country or region')

# %%
data_2019= merged_inner_2019.drop(['Country or region'], axis=1)
data_2019
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               6
# 1        Iceland                   Western Europe               4
# 2        Denmark                   Western Europe               2
# 3         Norway                   Western Europe               3
# 4         Canada                    North America               9
# ..           ...                              ...             ...
# 144       Rwanda               Sub-Saharan Africa             152
# 145        Benin               Sub-Saharan Africa             102
# 146        Syria  Middle East and Northern Africa             149
# 147      Burundi               Sub-Saharan Africa             145
# 148         Togo               Sub-Saharan Africa             139
#
#      Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0              7.480                     1.452                     1.052
# ...
