# %%
import pandas as pd
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
from sqlalchemy import create_engine

# %%
df_read_2015= pd.read_csv('datasets_894_813759_2015.csv')

# %%
df_read_2015.set_index('Country')
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
# array_2015 = df_read_2015.rename_axis('ID').values

# print(array_2015)

# %%
html2015 = df_read_2015.to_html()
print(html2015)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country</th>
#       <th>Region</th>
#       <th>Happiness Rank</th>
#       <th>Happiness Score</th>
#       <th>Economy (GDP per Capita)</th>
#       <th>Health (Life Expectancy)</th>
#       <th>Freedom</th>
#       <th>Trust (Government Corruption)</th>
#       <th>Generosity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Switzerland</td>
#       <td>Western Europe</td>
#       <td>1</td>
#       <td>7.587</td>
#       <td>1.39651</td>
#       <td>0.94143</td>
#       <td>0.66557</td>
#       <td>0.41978</td>
#       <td>0.29678</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Iceland</td>
#       <td>Western Europe</td>
#       <td>2</td>
#       <td>7.561</td>
#       <td>1.30232</td>
#       <td>0.94784</td>
#       <td>0.62877</td>
#       <td>0.14145</td>
#       <td>0.43630</td>
#     </tr>
#     <tr>
# ...

# %%
country_region= df_read_2015.drop(['Happiness Rank', 'Happiness Score',  'Economy (GDP per Capita)',  'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', ], axis=1)
# country_region

# %%
df_happiness_2016= pd.read_csv('datasets_894_813759_2016.csv')
df_happiness_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0              7.526                   1.44178                   0.79504
# ...

# %%
html2016 = df_happiness_2016.to_html()
print(html2016)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country</th>
#       <th>Region</th>
#       <th>Happiness Rank</th>
#       <th>Happiness Score</th>
#       <th>Economy (GDP per Capita)</th>
#       <th>Health (Life Expectancy)</th>
#       <th>Freedom</th>
#       <th>Trust (Government Corruption)</th>
#       <th>Generosity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Denmark</td>
#       <td>Western Europe</td>
#       <td>1</td>
#       <td>7.526</td>
#       <td>1.44178</td>
#       <td>0.79504</td>
#       <td>0.57941</td>
#       <td>0.44453</td>
#       <td>0.36171</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Switzerland</td>
#       <td>Western Europe</td>
#       <td>2</td>
#       <td>7.509</td>
#       <td>1.52733</td>
#       <td>0.86303</td>
#       <td>0.58557</td>
#       <td>0.41203</td>
#       <td>0.28083</td>
#     </tr>
#     <tr>
# ...

# %%
df_read_2017= pd.read_csv('datasets_894_813759_2017.csv')
df_happiness_2017 = df_read_2017.drop(['Whisker.high', 'Whisker.low'],axis=1)

# %%
df_merged_inner_2017 = pd.merge(left=country_region, right=happiness_2017, left_on='Country', right_on='Country')
# df_merged_inner_2017
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-bd46c9f626e4> in <module>
# ----> 1 df_merged_inner_2017 = pd.merge(left=country_region, right=happiness_2017, left_on='Country', right_on='Country')
#       2 # df_merged_inner_2017
#
# NameError: name 'happiness_2017' is not defined

# %%
df_happines_2017 = df_merged_inner_2017.sort_values("Happiness Rank")
df_happines_2017.head()

# %%
html2017 = df_happines_2017.to_html()
print(html2017)

# %%
df_happiness_2018= pd.read_csv('datasets_894_813759_2018.csv')

# %%
df_merged_inner_2018 = pd.merge(left=country_region, right=happiness_2018, left_on='Country', right_on='Country or region')

# %%
df_data_2018= df_merged_inner_2018.drop(['Country or region'], axis=1)
# df_data_2018

# %%
df_happines_2018 = df_data_2018.sort_values("Happiness Rank")
df_happines_2018.head()

# %%
html2018 = df_happines_2018.to_html()
print(html2018)

# %%
df_happiness_2019= pd.read_csv('datasets_894_813759_2019.csv')

# %%
df_merged_inner_2019 = pd.merge(left=country_region, right=happiness_2019, left_on='Country', right_on='Country or region')

# %%
df_data_2019= df_merged_inner_2019.drop(['Country or region'], axis=1)
# df_data_2019

# %%
df_happines_2019 = df_data_2019.sort_values("Happiness Rank")
df_happines_2019.head()

# %%
html2019 = df_happines_2019.to_html()
print(html2019)
